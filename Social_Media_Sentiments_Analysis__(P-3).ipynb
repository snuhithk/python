# %% [markdown]
# #importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #load dataset

# %%
#loading dataset
data = pd.read_csv('/content/drive/MyDrive/data set/sentimentdataset.csv')
data
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %% [markdown]
# #Basic analysis of the project :

# %%
#top rows
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
#bottom rows
data.tail()
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 727  Collaborating on a science project that receiv...    Happy
# 728  Attending a surprise birthday party organized ...    Happy
# 729  Successfully fundraising for a school charity ...    Happy
# 730  Participating in a multicultural festival, cel...    Happy
# 731  Organizing a virtual talent show during challe...    Happy
#
#                Timestamp                                   User     Platform  \
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# ...

# %%
#shape of the dataset
data.shape
# Out:
# (732, 15)

# %%
# columns in dataset
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Text', 'Sentiment', 'Timestamp', 'User',
#        'Platform', 'Hashtags', 'Retweets', 'Likes', 'Country', 'Year', 'Month',
#        'Day', 'Hour'],
#       dtype='object')

# %%
# information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
#description about the dataset

data.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
# finding that dataset is contains any null values
data.isna().any()
# Out:
# Unnamed: 0.1    False
# Unnamed: 0      False
# Text            False
# Sentiment       False
# Timestamp       False
# User            False
# Platform        False
# Hashtags        False
# Retweets        False
# Likes           False
# Country         False
# Year            False
# Month           False
# Day             False
# Hour            False
# dtype: bool

# %% [markdown]
# * no null values are presented in the dataset

# %%
# frequency of the elements in columns
data.value_counts()
# Out:
# Unnamed: 0.1  Unnamed: 0  Text                                                                                               Sentiment   Timestamp            User                                 Platform    Hashtags                                      Retweets  Likes  Country       Year  Month  Day  Hour
# 732           736         Organizing a virtual talent show during challenging times, bringing smiles to classmates' faces!   Happy       2020-11-15 15:15:00  VirtualTalentShowSuccessHighSchool   Instagram   #VirtualEntertainment #HighSchoolPositivity   24.0      47.0    USA          2020  11     15   15      1
# 0             0            Enjoying a beautiful day at the park!                                                             Positive    2023-01-15 12:30:00  User123                              Twitter     #Nature #Park                                 15.0      30.0    USA          2023  1      15   12      1
# ...

# %% [markdown]
# #visualization of the dataset :

# %%
# lineplot
plt.title('Lineplot')
sns.lineplot(x='Retweets',y='Likes',data=data)
# Out:
# <Axes: title={'center': 'Lineplot'}, xlabel='Retweets', ylabel='Likes'>

# %%
#barplot
plt.title('Barplot')
sns.barplot(x='Retweets',y='Likes',data=data)
# Out:
# <Axes: title={'center': 'Barplot'}, xlabel='Retweets', ylabel='Likes'>

# %%
#scatterplot
plt.title('Scatterplot')
sns.scatterplot(x='Retweets',y='Likes',hue='Year',data=data)
# Out:
# <Axes: title={'center': 'Scatterplot'}, xlabel='Retweets', ylabel='Likes'>

# %%
#histogram
plt.title('Histogram')
sns.histplot(x='Likes',data=data)
# Out:
# <Axes: title={'center': 'Histogram'}, xlabel='Likes', ylabel='Count'>

# %%
#countplot
plt.title('Countplot')
sns.countplot(x='Year',data=data)
# Out:
# <Axes: title={'center': 'Countplot'}, xlabel='Year', ylabel='count'>

# %%
#multi-variable
sns.pairplot(data)

# %% [markdown]
# #Questions :
# 1. What is the overall distribution of sentiments (positive, negative, neutral) across the posts?
# 2. Which platform generates the most engagement in terms of likes and retweets?
# 3. Which users have the highest average engagement (likes and retweets per post)?

# %% [markdown]
# #1. What is the overall distribution of sentiments (positive, negative, neutral) across the posts?

# %%
data1=data['Sentiment'].value_counts()
data1
# Out:
# Sentiment
# Positive            44
# Joy                 42
# Excitement          32
# Contentment         14
# Happy               14
#                     ..
# Loneliness           1
# Anxiety              1
# Renewed Effort       1
# Miscalculation       1
# Challenge            1
# Name: count, Length: 279, dtype: int64

# %%
dt=data1.head(10)
dt.plot(kind='bar')
plt.show()

# %% [markdown]
# # 2. Which platform generates the most engagement in terms of likes and retweets?

# %%
data2=data.groupby('Platform')[['Likes','Retweets']].sum()
data2
# Out:
#               Likes  Retweets
# Platform
# Facebook     9672.0    4844.0
# Instagram   11633.0    5831.0
# Twitter      5809.0    2918.0
# Twitter      4290.0    2151.0

# %%
data2.plot(kind='bar')
# Out:
# <Axes: xlabel='Platform'>

# %% [markdown]
# # 3.Which users have the highest average engagement (likes and retweets per post)?

# %%
data3=data.groupby('User')[['Likes','Retweets']].mean()
data3
# Out:
#                         Likes  Retweets
# User
# AbyssOfTime              45.0      22.0
# AcceptanceSeeker         30.0      15.0
# AdeleConcertGoer         80.0      40.0
# AdeleMelodyTearjerker    60.0      30.0
# AdventureAwaits          40.0      20.0
# ...                       ...       ...
# YearbookExplorer         25.0      12.0
# ZenLifestyle             30.0      15.0
# ZenMaster                30.0      15.0
# ZenMaster2               35.0      18.0
# ZenSeeker                70.0      35.0
#
# [685 rows x 2 columns]
